# %% [markdown]
# <a href="https://colab.research.google.com/github/ajipurnama25/TUGBES_IMAGE-RETRIEVAL_TKCA_122_131/blob/main/TUGAS_TKC_HISTOGRAM_122_131.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# hi_detect_low_contrast

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cfcb9797-0e76-49ef-8be6-f15a35b63079" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cfcb9797-0e76-49ef-8be6-f15a35b63079">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !pip install kaggle
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.10.8)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)

# %%
# !kaggle datasets download -d denizkavi1/brain-tumor
# Out:
# Downloading brain-tumor.zip to /content
# 100% 699M/700M [00:14<00:00, 33.3MB/s]
# 100% 700M/700M [00:14<00:00, 51.7MB/s]

# %%
# !unzip brain-tumor.zip
# Out:
# Archive:  brain-tumor.zip
#   inflating: 1/2300.png
#   inflating: 1/2301.png
#   inflating: 1/2302.png
#   inflating: 1/2303.png
#   inflating: 1/2304.png
#   inflating: 1/2305.png
#   inflating: 1/2306.png
#   inflating: 1/2307.png
#   inflating: 1/2308.png
#   inflating: 1/2309.png
#   inflating: 1/2310.png
#   inflating: 1/2311.png
#   inflating: 1/2312.png
#   inflating: 1/2313.png
#   inflating: 1/2314.png
#   inflating: 1/2315.png
#   inflating: 1/2316.png
#   inflating: 1/2317.png
#   inflating: 1/2318.png
#   inflating: 1/2319.png
#   inflating: 1/2320.png
#   inflating: 1/2321.png
#   inflating: 1/2322.png
#   inflating: 1/2323.png
#   inflating: 1/2324.png
#   inflating: 1/2325.png
#   inflating: 1/2326.png
#   inflating: 1/2327.png
#   inflating: 1/2328.png
#   inflating: 1/2329.png
#   inflating: 1/2330.png
#   inflating: 1/2331.png
#   inflating: 1/2332.png
#   inflating: 1/2333.png
#   inflating: 1/2334.png
#   inflating: 1/2335.png
#   inflating: 1/2336.png
#   inflating: 1/2337.png
#   inflating: 1/2338.png
#   inflating: 1/2339.png
#   inflating: 1/2340.png
#   inflating: 1/2341.png
#   inflating: 1/2342.png
#   inflating: 1/2343.png
#   inflating: 1/2344.png
#   inflating: 1/2345.png
#   inflating: 1/2346.png
#   inflating: 1/2347.png
#   inflating: 1/2348.png
#   inflating: 1/2349.png
#   inflating: 1/2350.png
#   inflating: 1/2351.png
#   inflating: 1/2352.png
#   inflating: 1/2353.png
#   inflating: 1/2354.png
#   inflating: 1/2355.png
#   inflating: 1/2356.png
#   inflating: 1/2357.png
#   inflating: 1/2358.png
#   inflating: 1/2359.png
#   inflating: 1/2360.png
#   inflating: 1/2361.png
#   inflating: 1/2362.png
#   inflating: 1/2363.png
#   inflating: 1/2364.png
#   inflating: 1/2365.png
#   inflating: 1/2366.png
#   inflating: 1/2367.png
#   inflating: 1/2368.png
#   inflating: 1/2369.png
#   inflating: 1/2370.png
#   inflating: 1/2371.png
#   inflating: 1/2372.png
#   inflating: 1/2373.png
#   inflating: 1/2374.png
#   inflating: 1/2375.png
#   inflating: 1/2376.png
#   inflating: 1/2377.png
#   inflating: 1/2378.png
#   inflating: 1/2379.png
#   inflating: 1/2380.png
#   inflating: 1/2381.png
#   inflating: 1/2382.png
#   inflating: 1/2383.png
#   inflating: 1/2384.png
#   inflating: 1/2385.png
#   inflating: 1/2386.png
#   inflating: 1/2387.png
#   inflating: 1/2388.png
#   inflating: 1/2389.png
#   inflating: 1/2390.png
#   inflating: 1/2391.png
#   inflating: 1/2392.png
#   inflating: 1/2393.png
#   inflating: 1/2394.png
#   inflating: 1/2395.png
#   inflating: 1/2396.png
#   inflating: 1/2397.png
#   inflating: 1/2398.png
#   inflating: 1/2399.png
#   inflating: 1/2400.png
#   inflating: 1/2401.png
#   inflating: 1/2402.png
#   inflating: 1/2403.png
#   inflating: 1/2404.png
#   inflating: 1/2405.png
#   inflating: 1/2406.png
#   inflating: 1/2407.png
#   inflating: 1/2408.png
#   inflating: 1/2409.png
#   inflating: 1/2410.png
#   inflating: 1/2411.png
#   inflating: 1/2412.png
#   inflating: 1/2413.png
#   inflating: 1/2414.png
#   inflating: 1/2415.png
#   inflating: 1/2416.png
#   inflating: 1/2417.png
#   inflating: 1/2418.png
#   inflating: 1/2419.png
#   inflating: 1/2420.png
#   inflating: 1/2421.png
#   inflating: 1/2422.png
#   inflating: 1/2423.png
#   inflating: 1/2424.png
#   inflating: 1/2425.png
#   inflating: 1/2426.png
#   inflating: 1/2427.png
#   inflating: 1/2428.png
#   inflating: 1/2429.png
#   inflating: 1/2430.png
#   inflating: 1/2431.png
#   inflating: 1/2432.png
#   inflating: 1/2433.png
#   inflating: 1/2434.png
#   inflating: 1/2435.png
#   inflating: 1/2436.png
#   inflating: 1/2437.png
#   inflating: 1/2438.png
#   inflating: 1/2439.png
#   inflating: 1/2440.png
#   inflating: 1/2441.png
#   inflating: 1/2442.png
#   inflating: 1/2443.png
#   inflating: 1/2444.png
#   inflating: 1/2445.png
#   inflating: 1/2446.png
#   inflating: 1/2447.png
#   inflating: 1/2448.png
#   inflating: 1/2449.png
#   inflating: 1/2450.png
#   inflating: 1/2451.png
#   inflating: 1/2452.png
#   inflating: 1/2453.png
#   inflating: 1/2454.png
#   inflating: 1/2455.png
#   inflating: 1/2456.png
#   inflating: 1/2457.png
#   inflating: 1/2458.png
#   inflating: 1/2459.png
#   inflating: 1/2460.png
#   inflating: 1/2461.png
#   inflating: 1/2462.png
#   inflating: 1/2463.png
#   inflating: 1/2464.png
#   inflating: 1/2465.png
#   inflating: 1/2466.png
#   inflating: 1/2467.png
#   inflating: 1/2468.png
#   inflating: 1/2469.png
#   inflating: 1/2470.png
#   inflating: 1/2471.png
#   inflating: 1/2472.png
#   inflating: 1/2473.png
#   inflating: 1/2474.png
#   inflating: 1/2475.png
#   inflating: 1/2476.png
#   inflating: 1/2477.png
#   inflating: 1/2478.png
#   inflating: 1/2479.png
#   inflating: 1/2480.png
#   inflating: 1/2481.png
#   inflating: 1/2482.png
#   inflating: 1/2483.png
#   inflating: 1/2484.png
#   inflating: 1/2485.png
#   inflating: 1/2486.png
#   inflating: 1/2487.png
#   inflating: 1/2488.png
#   inflating: 1/2489.png
#   inflating: 1/2490.png
#   inflating: 1/2491.png
#   inflating: 1/2492.png
#   inflating: 1/2493.png
#   inflating: 1/2494.png
#   inflating: 1/2495.png
#   inflating: 1/2496.png
#   inflating: 1/2497.png
#   inflating: 1/2498.png
#   inflating: 1/2499.png
#   inflating: 1/2500.png
#   inflating: 1/2501.png
#   inflating: 1/2502.png
#   inflating: 1/2503.png
#   inflating: 1/2504.png
#   inflating: 1/2505.png
#   inflating: 1/2506.png
#   inflating: 1/2507.png
#   inflating: 1/2508.png
#   inflating: 1/2509.png
#   inflating: 1/2510.png
#   inflating: 1/2511.png
#   inflating: 1/2512.png
#   inflating: 1/2513.png
#   inflating: 1/2514.png
#   inflating: 1/2515.png
#   inflating: 1/2516.png
#   inflating: 1/2517.png
#   inflating: 1/2518.png
#   inflating: 1/2519.png
#   inflating: 1/2520.png
#   inflating: 1/2521.png
#   inflating: 1/2522.png
#   inflating: 1/2523.png
#   inflating: 1/2524.png
#   inflating: 1/2525.png
#   inflating: 1/2526.png
#   inflating: 1/2527.png
#   inflating: 1/2528.png
#   inflating: 1/2529.png
#   inflating: 1/2530.png
#   inflating: 1/2531.png
#   inflating: 1/2532.png
#   inflating: 1/2533.png
#   inflating: 1/2534.png
#   inflating: 1/2535.png
#   inflating: 1/2536.png
#   inflating: 1/2537.png
#   inflating: 1/2538.png
#   inflating: 1/2539.png
#   inflating: 1/2540.png
#   inflating: 1/2541.png
#   inflating: 1/2542.png
#   inflating: 1/2543.png
#   inflating: 1/2544.png
#   inflating: 1/2545.png
#   inflating: 1/2546.png
#   inflating: 1/2547.png
#   inflating: 1/2548.png
#   inflating: 1/2549.png
#   inflating: 1/2550.png
#   inflating: 1/2551.png
#   inflating: 1/2552.png
#   inflating: 1/2553.png
#   inflating: 1/2554.png
#   inflating: 1/2555.png
#   inflating: 1/2556.png
#   inflating: 1/2557.png
#   inflating: 1/2558.png
#   inflating: 1/2559.png
#   inflating: 1/2560.png
#   inflating: 1/2561.png
#   inflating: 1/2562.png
#   inflating: 1/2563.png
#   inflating: 1/2564.png
#   inflating: 1/2565.png
#   inflating: 1/2566.png
#   inflating: 1/2567.png
#   inflating: 1/2568.png
#   inflating: 1/2569.png
#   inflating: 1/2570.png
#   inflating: 1/2571.png
#   inflating: 1/2572.png
#   inflating: 1/2573.png
#   inflating: 1/2574.png
#   inflating: 1/2575.png
#   inflating: 1/2576.png
#   inflating: 1/2577.png
#   inflating: 1/2578.png
#   inflating: 1/2579.png
#   inflating: 1/2580.png
#   inflating: 1/2581.png
#   inflating: 1/2582.png
#   inflating: 1/2583.png
#   inflating: 1/2584.png
#   inflating: 1/2585.png
#   inflating: 1/2586.png
#   inflating: 1/2587.png
#   inflating: 1/2588.png
#   inflating: 1/2589.png
#   inflating: 1/2590.png
#   inflating: 1/2591.png
#   inflating: 1/2592.png
#   inflating: 1/2593.png
#   inflating: 1/2594.png
#   inflating: 1/2595.png
#   inflating: 1/2596.png
#   inflating: 1/2597.png
#   inflating: 1/2598.png
#   inflating: 1/2599.png
#   inflating: 1/2600.png
#   inflating: 1/2601.png
#   inflating: 1/2602.png
#   inflating: 1/2603.png
#   inflating: 1/2604.png
#   inflating: 1/2605.png
#   inflating: 1/2606.png
#   inflating: 1/2607.png
#   inflating: 1/2608.png
#   inflating: 1/2609.png
#   inflating: 1/2610.png
#   inflating: 1/2611.png
#   inflating: 1/2612.png
#   inflating: 1/2613.png
#   inflating: 1/2614.png
#   inflating: 1/2615.png
#   inflating: 1/2616.png
#   inflating: 1/2617.png
#   inflating: 1/2618.png
#   inflating: 1/2619.png
#   inflating: 1/2620.png
#   inflating: 1/2621.png
#   inflating: 1/2622.png
#   inflating: 1/2623.png
#   inflating: 1/2624.png
#   inflating: 1/2625.png
#   inflating: 1/2626.png
#   inflating: 1/2627.png
#   inflating: 1/2628.png
#   inflating: 1/2629.png
#   inflating: 1/2630.png
#   inflating: 1/2631.png
#   inflating: 1/2632.png
#   inflating: 1/2633.png
#   inflating: 1/2634.png
#   inflating: 1/2635.png
#   inflating: 1/2636.png
#   inflating: 1/2637.png
#   inflating: 1/2638.png
#   inflating: 1/2639.png
#   inflating: 1/2640.png
#   inflating: 1/2641.png
#   inflating: 1/2642.png
#   inflating: 1/2643.png
#   inflating: 1/2644.png
#   inflating: 1/2645.png
#   inflating: 1/2646.png
#   inflating: 1/2647.png
#   inflating: 1/2648.png
#   inflating: 1/2649.png
#   inflating: 1/2650.png
#   inflating: 1/2651.png
#   inflating: 1/2652.png
#   inflating: 1/2653.png
#   inflating: 1/2654.png
#   inflating: 1/2655.png
#   inflating: 1/2656.png
#   inflating: 1/2657.png
#   inflating: 1/2658.png
#   inflating: 1/2659.png
#   inflating: 1/2660.png
#   inflating: 1/2661.png
#   inflating: 1/2662.png
#   inflating: 1/2663.png
#   inflating: 1/2664.png
#   inflating: 1/2665.png
#   inflating: 1/2666.png
#   inflating: 1/2667.png
#   inflating: 1/2668.png
#   inflating: 1/2669.png
#   inflating: 1/2670.png
#   inflating: 1/2671.png
#   inflating: 1/2672.png
#   inflating: 1/2673.png
#   inflating: 1/2674.png
#   inflating: 1/2675.png
#   inflating: 1/2676.png
#   inflating: 1/2677.png
#   inflating: 1/2678.png
#   inflating: 1/2679.png
#   inflating: 1/2680.png
#   inflating: 1/2681.png
#   inflating: 1/2682.png
#   inflating: 1/2683.png
#   inflating: 1/2684.png
#   inflating: 1/2685.png
#   inflating: 1/2686.png
#   inflating: 1/2687.png
#   inflating: 1/2688.png
#   inflating: 1/2689.png
#   inflating: 1/2690.png
#   inflating: 1/2691.png
#   inflating: 1/2692.png
#   inflating: 1/2694.png
#   inflating: 1/2695.png
#   inflating: 1/2696.png
#   inflating: 1/2697.png
#   inflating: 1/2699.png
#   inflating: 1/2701.png
#   inflating: 1/2702.png
#   inflating: 1/2703.png
#   inflating: 1/2704.png
#   inflating: 1/2706.png
#   inflating: 1/2760.png
#   inflating: 1/2761.png
#   inflating: 1/2762.png
#   inflating: 1/2763.png
#   inflating: 1/2764.png
#   inflating: 1/2765.png
#   inflating: 1/2766.png
#   inflating: 1/2767.png
#   inflating: 1/2768.png
#   inflating: 1/2769.png
#   inflating: 1/2770.png
#   inflating: 1/2771.png
#   inflating: 1/2772.png
#   inflating: 1/2773.png
#   inflating: 1/2774.png
#   inflating: 1/2775.png
#   inflating: 1/2776.png
#   inflating: 1/2777.png
#   inflating: 1/2778.png
#   inflating: 1/2779.png
#   inflating: 1/2780.png
#   inflating: 1/2781.png
#   inflating: 1/2782.png
#   inflating: 1/2783.png
#   inflating: 1/2784.png
#   inflating: 1/2785.png
#   inflating: 1/2786.png
#   inflating: 1/2787.png
#   inflating: 1/2788.png
#   inflating: 1/2789.png
#   inflating: 1/2790.png
#   inflating: 1/2791.png
#   inflating: 1/2792.png
#   inflating: 1/2793.png
#   inflating: 1/2794.png
#   inflating: 1/2795.png
#   inflating: 1/2796.png
#   inflating: 1/2797.png
#   inflating: 1/2798.png
#   inflating: 1/2799.png
#   inflating: 1/2800.png
#   inflating: 1/2801.png
#   inflating: 1/2802.png
#   inflating: 1/2803.png
#   inflating: 1/2804.png
#   inflating: 1/2805.png
#   inflating: 1/2806.png
#   inflating: 1/2807.png
#   inflating: 1/2808.png
#   inflating: 1/2809.png
#   inflating: 1/2810.png
#   inflating: 1/2811.png
#   inflating: 1/2812.png
#   inflating: 1/2813.png
#   inflating: 1/2814.png
#   inflating: 1/2815.png
#   inflating: 1/2816.png
#   inflating: 1/2817.png
#   inflating: 1/2818.png
#   inflating: 1/2819.png
#   inflating: 1/2820.png
#   inflating: 1/2822.png
#   inflating: 1/2823.png
#   inflating: 1/2824.png
#   inflating: 1/2825.png
#   inflating: 1/2826.png
#   inflating: 1/2827.png
#   inflating: 1/2828.png
#   inflating: 1/2829.png
#   inflating: 1/2830.png
#   inflating: 1/2831.png
#   inflating: 1/2832.png
#   inflating: 1/2833.png
#   inflating: 1/2834.png
#   inflating: 1/2835.png
#   inflating: 1/2836.png
#   inflating: 1/2837.png
#   inflating: 1/2838.png
#   inflating: 1/2839.png
#   inflating: 1/2840.png
#   inflating: 1/2841.png
#   inflating: 1/2842.png
#   inflating: 1/2843.png
#   inflating: 1/2844.png
#   inflating: 1/2845.png
#   inflating: 1/2846.png
#   inflating: 1/2847.png
#   inflating: 1/2848.png
#   inflating: 1/2849.png
#   inflating: 1/2850.png
#   inflating: 1/2851.png
#   inflating: 1/2852.png
#   inflating: 1/2853.png
#   inflating: 1/2854.png
#   inflating: 1/2855.png
#   inflating: 1/2856.png
#   inflating: 1/2857.png
#   inflating: 1/2858.png
#   inflating: 1/2859.png
#   inflating: 1/2860.png
#   inflating: 1/2861.png
#   inflating: 1/2862.png
#   inflating: 1/2863.png
#   inflating: 1/2864.png
#   inflating: 1/2865.png
#   inflating: 1/2866.png
#   inflating: 1/2867.png
#   inflating: 1/2868.png
#   inflating: 1/2869.png
#   inflating: 1/2870.png
#   inflating: 1/2871.png
#   inflating: 1/2872.png
#   inflating: 1/2873.png
#   inflating: 1/2874.png
#   inflating: 1/2875.png
#   inflating: 1/2876.png
#   inflating: 1/2877.png
#   inflating: 1/2878.png
#   inflating: 1/2879.png
#   inflating: 1/2880.png
#   inflating: 1/2881.png
#   inflating: 1/2882.png
#   inflating: 1/2883.png
#   inflating: 1/2884.png
#   inflating: 1/2885.png
#   inflating: 1/2886.png
#   inflating: 1/2887.png
#   inflating: 1/2888.png
#   inflating: 1/2889.png
#   inflating: 1/2890.png
#   inflating: 1/2891.png
#   inflating: 1/2892.png
#   inflating: 1/2893.png
#   inflating: 1/2894.png
#   inflating: 1/2895.png
#   inflating: 1/2896.png
#   inflating: 1/2897.png
#   inflating: 1/2898.png
#   inflating: 1/2899.png
#   inflating: 1/2900.png
#   inflating: 1/2901.png
#   inflating: 1/2902.png
#   inflating: 1/2903.png
#   inflating: 1/2904.png
#   inflating: 1/2905.png
#   inflating: 1/2906.png
#   inflating: 1/2907.png
#   inflating: 1/2908.png
#   inflating: 1/2909.png
#   inflating: 1/2910.png
#   inflating: 1/2911.png
#   inflating: 1/2912.png
#   inflating: 1/2913.png
#   inflating: 1/2914.png
#   inflating: 1/2915.png
#   inflating: 1/2916.png
#   inflating: 1/2917.png
#   inflating: 1/2918.png
#   inflating: 1/2919.png
#   inflating: 1/2920.png
#   inflating: 1/2921.png
#   inflating: 1/2922.png
#   inflating: 1/2923.png
#   inflating: 1/2924.png
#   inflating: 1/2925.png
#   inflating: 1/2926.png
#   inflating: 1/2927.png
#   inflating: 1/2928.png
#   inflating: 1/2929.png
#   inflating: 1/2930.png
#   inflating: 1/2931.png
#   inflating: 1/2932.png
#   inflating: 1/2933.png
#   inflating: 1/2934.png
#   inflating: 1/2935.png
#   inflating: 1/2936.png
#   inflating: 1/2937.png
#   inflating: 1/2938.png
#   inflating: 1/2939.png
#   inflating: 1/2940.png
#   inflating: 1/2941.png
#   inflating: 1/2942.png
#   inflating: 1/2943.png
#   inflating: 1/2944.png
#   inflating: 1/2946.png
#   inflating: 1/2947.png
#   inflating: 1/2948.png
#   inflating: 1/2949.png
#   inflating: 1/2950.png
#   inflating: 1/2951.png
#   inflating: 1/2952.png
#   inflating: 1/2953.png
#   inflating: 1/2954.png
#   inflating: 1/2955.png
#   inflating: 1/2956.png
#   inflating: 1/2957.png
#   inflating: 1/2958.png
#   inflating: 1/2959.png
#   inflating: 1/2961.png
#   inflating: 1/2962.png
#   inflating: 1/2963.png
#   inflating: 1/2964.png
#   inflating: 1/2965.png
#   inflating: 1/2966.png
#   inflating: 1/2967.png
#   inflating: 1/2968.png
#   inflating: 1/2969.png
#   inflating: 1/2970.png
#   inflating: 1/2971.png
#   inflating: 1/2972.png
#   inflating: 1/2973.png
#   inflating: 1/2974.png
#   inflating: 1/2975.png
#   inflating: 1/2976.png
#   inflating: 1/2977.png
#   inflating: 1/2978.png
#   inflating: 1/2979.png
#   inflating: 1/2980.png
#   inflating: 1/2981.png
#   inflating: 1/2982.png
#   inflating: 1/2983.png
#   inflating: 1/2984.png
#   inflating: 1/2985.png
#   inflating: 1/2986.png
#   inflating: 1/2987.png
#   inflating: 1/2988.png
#   inflating: 1/2989.png
#   inflating: 1/2990.png
#   inflating: 1/2991.png
#   inflating: 1/2992.png
#   inflating: 1/2993.png
#   inflating: 1/2994.png
#   inflating: 1/2995.png
#   inflating: 1/2996.png
#   inflating: 1/2997.png
#   inflating: 1/2998.png
#   inflating: 1/2999.png
#   inflating: 1/3000.png
#   inflating: 1/3001.png
#   inflating: 1/3002.png
#   inflating: 1/3003.png
#   inflating: 1/3004.png
#   inflating: 1/3005.png
#   inflating: 1/3006.png
#   inflating: 1/3007.png
#   inflating: 1/3008.png
#   inflating: 1/3009.png
#   inflating: 1/3010.png
#   inflating: 1/3011.png
#   inflating: 1/3012.png
#   inflating: 1/3013.png
#   inflating: 1/3014.png
#   inflating: 1/3015.png
#   inflating: 1/3016.png
#   inflating: 1/3017.png
#   inflating: 1/3018.png
#   inflating: 1/3019.png
#   inflating: 1/3020.png
#   inflating: 1/3021.png
#   inflating: 1/3022.png
#   inflating: 1/3023.png
#   inflating: 1/3024.png
#   inflating: 1/3025.png
#   inflating: 1/3026.png
#   inflating: 1/3027.png
#   inflating: 1/3028.png
#   inflating: 1/3029.png
#   inflating: 1/3030.png
#   inflating: 1/3031.png
#   inflating: 1/3032.png
#   inflating: 1/3033.png
#   inflating: 1/3034.png
#   inflating: 1/3035.png
#   inflating: 1/3036.png
#   inflating: 1/3037.png
#   inflating: 1/3038.png
#   inflating: 1/3039.png
#   inflating: 1/3040.png
#   inflating: 1/3041.png
#   inflating: 1/3042.png
#   inflating: 1/3043.png
#   inflating: 1/3044.png
#   inflating: 1/3045.png
#   inflating: 1/3046.png
#   inflating: 1/3047.png
#   inflating: 1/3048.png
#   inflating: 1/3049.png
#   inflating: 1/3050.png
#   inflating: 1/3051.png
#   inflating: 1/3052.png
#   inflating: 1/3053.png
#   inflating: 1/3054.png
#   inflating: 1/3055.png
#   inflating: 1/3056.png
#   inflating: 1/3057.png
#   inflating: 1/3058.png
#   inflating: 1/3059.png
#   inflating: 1/3060.png
#   inflating: 1/3061.png
#   inflating: 1/3062.png
#   inflating: 1/3063.png
#   inflating: 1/423.png
#   inflating: 1/456.png
#   inflating: 1/457.png
#   inflating: 1/459.png
#   inflating: 2/0.png
#   inflating: 2/1.png
#   inflating: 2/10.png
#   inflating: 2/100.png
#   inflating: 2/101.png
#   inflating: 2/102.png
#   inflating: 2/103.png
#   inflating: 2/104.png
#   inflating: 2/105.png
#   inflating: 2/106.png
#   inflating: 2/107.png
#   inflating: 2/1073.png
#   inflating: 2/1074.png
#   inflating: 2/1075.png
#   inflating: 2/1076.png
#   inflating: 2/1077.png
#   inflating: 2/1078.png
#   inflating: 2/1079.png
#   inflating: 2/108.png
#   inflating: 2/1080.png
#   inflating: 2/1083.png
#   inflating: 2/1084.png
#   inflating: 2/1085.png
#   inflating: 2/1086.png
#   inflating: 2/1087.png
#   inflating: 2/1088.png
#   inflating: 2/1089.png
#   inflating: 2/109.png
#   inflating: 2/1090.png
#   inflating: 2/1091.png
#   inflating: 2/1092.png
#   inflating: 2/1093.png
#   inflating: 2/1094.png
#   inflating: 2/1095.png
#   inflating: 2/1096.png
#   inflating: 2/1097.png
#   inflating: 2/1098.png
#   inflating: 2/1099.png
#   inflating: 2/11.png
#   inflating: 2/110.png
#   inflating: 2/1100.png
#   inflating: 2/1101.png
#   inflating: 2/1102.png
#   inflating: 2/1103.png
#   inflating: 2/1104.png
#   inflating: 2/1105.png
#   inflating: 2/1106.png
#   inflating: 2/1107.png
#   inflating: 2/1108.png
#   inflating: 2/1109.png
#   inflating: 2/111.png
#   inflating: 2/1110.png
#   inflating: 2/1111.png
#   inflating: 2/1112.png
#   inflating: 2/1113.png
#   inflating: 2/1114.png
#   inflating: 2/1115.png
#   inflating: 2/1116.png
#   inflating: 2/1117.png
#   inflating: 2/1118.png
#   inflating: 2/1119.png
#   inflating: 2/112.png
#   inflating: 2/1120.png
#   inflating: 2/1121.png
#   inflating: 2/1122.png
#   inflating: 2/1123.png
#   inflating: 2/1124.png
#   inflating: 2/1125.png
#   inflating: 2/1126.png
#   inflating: 2/1127.png
#   inflating: 2/1128.png
#   inflating: 2/1129.png
#   inflating: 2/113.png
#   inflating: 2/1130.png
#   inflating: 2/1131.png
#   inflating: 2/1132.png
#   inflating: 2/1133.png
#   inflating: 2/1134.png
#   inflating: 2/1135.png
#   inflating: 2/1136.png
#   inflating: 2/1137.png
#   inflating: 2/1138.png
#   inflating: 2/1139.png
#   inflating: 2/114.png
#   inflating: 2/1140.png
#   inflating: 2/1141.png
#   inflating: 2/1142.png
#   inflating: 2/1143.png
#   inflating: 2/1144.png
#   inflating: 2/1145.png
#   inflating: 2/1146.png
#   inflating: 2/1147.png
#   inflating: 2/1148.png
#   inflating: 2/1149.png
#   inflating: 2/115.png
#   inflating: 2/1150.png
#   inflating: 2/1151.png
#   inflating: 2/1152.png
#   inflating: 2/1153.png
#   inflating: 2/1154.png
#   inflating: 2/1155.png
#   inflating: 2/1156.png
#   inflating: 2/1157.png
#   inflating: 2/1158.png
#   inflating: 2/1159.png
#   inflating: 2/116.png
#   inflating: 2/1160.png
#   inflating: 2/1161.png
#   inflating: 2/1162.png
#   inflating: 2/1163.png
#   inflating: 2/1164.png
#   inflating: 2/1165.png
#   inflating: 2/1166.png
#   inflating: 2/1167.png
#   inflating: 2/1168.png
#   inflating: 2/1169.png
#   inflating: 2/117.png
#   inflating: 2/1170.png
#   inflating: 2/1171.png
#   inflating: 2/1172.png
#   inflating: 2/1173.png
#   inflating: 2/1174.png
#   inflating: 2/1175.png
#   inflating: 2/1176.png
#   inflating: 2/1177.png
#   inflating: 2/1178.png
#   inflating: 2/1179.png
#   inflating: 2/118.png
#   inflating: 2/1180.png
#   inflating: 2/1181.png
#   inflating: 2/1182.png
#   inflating: 2/1183.png
#   inflating: 2/1184.png
#   inflating: 2/1185.png
#   inflating: 2/1186.png
#   inflating: 2/1187.png
#   inflating: 2/1188.png
#   inflating: 2/1189.png
#   inflating: 2/119.png
#   inflating: 2/1190.png
#   inflating: 2/1191.png
#   inflating: 2/1192.png
#   inflating: 2/1193.png
#   inflating: 2/1194.png
#   inflating: 2/1195.png
#   inflating: 2/1196.png
#   inflating: 2/1197.png
#   inflating: 2/1198.png
#   inflating: 2/1199.png
#   inflating: 2/12.png
#   inflating: 2/120.png
#   inflating: 2/1200.png
#   inflating: 2/1201.png
#   inflating: 2/1202.png
#   inflating: 2/1203.png
#   inflating: 2/1204.png
#   inflating: 2/1205.png
#   inflating: 2/1206.png
#   inflating: 2/1207.png
#   inflating: 2/1208.png
#   inflating: 2/1209.png
#   inflating: 2/121.png
#   inflating: 2/1210.png
#   inflating: 2/1211.png
#   inflating: 2/1212.png
#   inflating: 2/1213.png
#   inflating: 2/1214.png
#   inflating: 2/1215.png
#   inflating: 2/1216.png
#   inflating: 2/1217.png
#   inflating: 2/1218.png
#   inflating: 2/1219.png
#   inflating: 2/122.png
#   inflating: 2/1220.png
#   inflating: 2/1221.png
#   inflating: 2/1222.png
#   inflating: 2/1223.png
#   inflating: 2/1224.png
#   inflating: 2/1225.png
#   inflating: 2/1226.png
#   inflating: 2/1227.png
#   inflating: 2/1228.png
#   inflating: 2/1229.png
#   inflating: 2/123.png
#   inflating: 2/1230.png
#   inflating: 2/1231.png
#   inflating: 2/1232.png
#   inflating: 2/1233.png
#   inflating: 2/1234.png
#   inflating: 2/1235.png
#   inflating: 2/1236.png
#   inflating: 2/1237.png
#   inflating: 2/1238.png
#   inflating: 2/1239.png
#   inflating: 2/124.png
#   inflating: 2/1240.png
#   inflating: 2/1241.png
#   inflating: 2/1242.png
#   inflating: 2/1243.png
#   inflating: 2/1244.png
#   inflating: 2/1245.png
#   inflating: 2/1246.png
#   inflating: 2/1247.png
#   inflating: 2/1248.png
#   inflating: 2/1249.png
#   inflating: 2/125.png
#   inflating: 2/1250.png
#   inflating: 2/1251.png
#   inflating: 2/1252.png
#   inflating: 2/1253.png
#   inflating: 2/1254.png
#   inflating: 2/1255.png
#   inflating: 2/1256.png
#   inflating: 2/1257.png
#   inflating: 2/1258.png
#   inflating: 2/1259.png
#   inflating: 2/126.png
#   inflating: 2/1260.png
#   inflating: 2/1261.png
#   inflating: 2/1262.png
#   inflating: 2/1263.png
#   inflating: 2/1264.png
#   inflating: 2/1265.png
#   inflating: 2/1266.png
#   inflating: 2/1267.png
#   inflating: 2/1268.png
#   inflating: 2/1269.png
#   inflating: 2/127.png
#   inflating: 2/1270.png
#   inflating: 2/1271.png
#   inflating: 2/1272.png
#   inflating: 2/1273.png
#   inflating: 2/1274.png
#   inflating: 2/1275.png
#   inflating: 2/1276.png
#   inflating: 2/1277.png
#   inflating: 2/1278.png
#   inflating: 2/1279.png
#   inflating: 2/128.png
#   inflating: 2/1280.png
#   inflating: 2/1281.png
#   inflating: 2/1282.png
#   inflating: 2/1283.png
#   inflating: 2/1284.png
#   inflating: 2/1285.png
#   inflating: 2/1286.png
#   inflating: 2/1287.png
#   inflating: 2/1288.png
#   inflating: 2/1289.png
#   inflating: 2/129.png
#   inflating: 2/1290.png
#   inflating: 2/1291.png
#   inflating: 2/1292.png
#   inflating: 2/1293.png
#   inflating: 2/1294.png
#   inflating: 2/1295.png
#   inflating: 2/1296.png
#   inflating: 2/1297.png
#   inflating: 2/1298.png
#   inflating: 2/1299.png
#   inflating: 2/13.png
#   inflating: 2/130.png
#   inflating: 2/1300.png
#   inflating: 2/1301.png
#   inflating: 2/1302.png
#   inflating: 2/1303.png
#   inflating: 2/1304.png
#   inflating: 2/1305.png
#   inflating: 2/1306.png
#   inflating: 2/1307.png
#   inflating: 2/1308.png
#   inflating: 2/1309.png
#   inflating: 2/131.png
#   inflating: 2/1310.png
#   inflating: 2/1311.png
#   inflating: 2/1312.png
#   inflating: 2/1313.png
#   inflating: 2/1314.png
#   inflating: 2/1315.png
#   inflating: 2/1316.png
#   inflating: 2/1317.png
#   inflating: 2/1318.png
#   inflating: 2/1319.png
#   inflating: 2/132.png
#   inflating: 2/1320.png
#   inflating: 2/1321.png
#   inflating: 2/1322.png
#   inflating: 2/1323.png
#   inflating: 2/1324.png
#   inflating: 2/1325.png
#   inflating: 2/1326.png
#   inflating: 2/1327.png
#   inflating: 2/1328.png
#   inflating: 2/1329.png
#   inflating: 2/133.png
#   inflating: 2/1330.png
#   inflating: 2/1331.png
#   inflating: 2/1332.png
#   inflating: 2/1333.png
#   inflating: 2/1334.png
#   inflating: 2/1335.png
#   inflating: 2/1336.png
#   inflating: 2/1337.png
#   inflating: 2/1338.png
#   inflating: 2/1339.png
#   inflating: 2/134.png
#   inflating: 2/1340.png
#   inflating: 2/1341.png
#   inflating: 2/1342.png
#   inflating: 2/1343.png
#   inflating: 2/1344.png
#   inflating: 2/1345.png
#   inflating: 2/1346.png
#   inflating: 2/1347.png
#   inflating: 2/1348.png
#   inflating: 2/1349.png
#   inflating: 2/135.png
#   inflating: 2/1350.png
#   inflating: 2/1351.png
#   inflating: 2/1352.png
#   inflating: 2/1353.png
#   inflating: 2/1354.png
#   inflating: 2/1355.png
#   inflating: 2/1356.png
#   inflating: 2/1357.png
#   inflating: 2/1358.png
#   inflating: 2/1359.png
#   inflating: 2/136.png
#   inflating: 2/1360.png
#   inflating: 2/1361.png
#   inflating: 2/1362.png
#   inflating: 2/1363.png
#   inflating: 2/1364.png
#   inflating: 2/1365.png
#   inflating: 2/1366.png
#   inflating: 2/1367.png
#   inflating: 2/1368.png
#   inflating: 2/1369.png
#   inflating: 2/137.png
#   inflating: 2/1370.png
#   inflating: 2/1371.png
#   inflating: 2/1372.png
#   inflating: 2/1373.png
#   inflating: 2/1374.png
#   inflating: 2/1375.png
#   inflating: 2/1376.png
#   inflating: 2/1377.png
#   inflating: 2/1378.png
#   inflating: 2/1379.png
#   inflating: 2/138.png
#   inflating: 2/139.png
#   inflating: 2/14.png
#   inflating: 2/140.png
#   inflating: 2/141.png
#   inflating: 2/142.png
#   inflating: 2/143.png
#   inflating: 2/144.png
#   inflating: 2/145.png
#   inflating: 2/146.png
#   inflating: 2/147.png
#   inflating: 2/148.png
#   inflating: 2/149.png
#   inflating: 2/15.png
#   inflating: 2/150.png
#   inflating: 2/151.png
#   inflating: 2/152.png
#   inflating: 2/153.png
#   inflating: 2/154.png
#   inflating: 2/155.png
#   inflating: 2/156.png
#   inflating: 2/157.png
#   inflating: 2/158.png
#   inflating: 2/159.png
#   inflating: 2/16.png
#   inflating: 2/160.png
#   inflating: 2/161.png
#   inflating: 2/162.png
#   inflating: 2/163.png
#   inflating: 2/164.png
#   inflating: 2/165.png
#   inflating: 2/166.png
#   inflating: 2/167.png
#   inflating: 2/168.png
#   inflating: 2/169.png
#   inflating: 2/17.png
#   inflating: 2/170.png
#   inflating: 2/171.png
#   inflating: 2/172.png
#   inflating: 2/173.png
#   inflating: 2/174.png
#   inflating: 2/175.png
#   inflating: 2/176.png
#   inflating: 2/177.png
#   inflating: 2/178.png
#   inflating: 2/179.png
#   inflating: 2/18.png
#   inflating: 2/180.png
#   inflating: 2/181.png
#   inflating: 2/182.png
#   inflating: 2/183.png
#   inflating: 2/184.png
#   inflating: 2/1840.png
#   inflating: 2/1841.png
#   inflating: 2/1842.png
#   inflating: 2/1843.png
#   inflating: 2/1844.png
#   inflating: 2/1845.png
#   inflating: 2/1846.png
#   inflating: 2/1847.png
#   inflating: 2/1848.png
#   inflating: 2/1849.png
#   inflating: 2/185.png
#   inflating: 2/1850.png
#   inflating: 2/1851.png
#   inflating: 2/1852.png
#   inflating: 2/1853.png
#   inflating: 2/1854.png
#   inflating: 2/1855.png
#   inflating: 2/1856.png
#   inflating: 2/1857.png
#   inflating: 2/1858.png
#   inflating: 2/1859.png
#   inflating: 2/186.png
#   inflating: 2/1860.png
#   inflating: 2/1861.png
#   inflating: 2/1862.png
#   inflating: 2/1863.png
#   inflating: 2/1864.png
#   inflating: 2/1865.png
#   inflating: 2/1866.png
#   inflating: 2/1867.png
#   inflating: 2/1868.png
#   inflating: 2/1869.png
#   inflating: 2/187.png
#   inflating: 2/1870.png
#   inflating: 2/1871.png
#   inflating: 2/1872.png
#   inflating: 2/1873.png
#   inflating: 2/1874.png
#   inflating: 2/1875.png
#   inflating: 2/1876.png
#   inflating: 2/1877.png
#   inflating: 2/1878.png
#   inflating: 2/1879.png
#   inflating: 2/188.png
#   inflating: 2/1880.png
#   inflating: 2/1881.png
#   inflating: 2/1882.png
#   inflating: 2/1883.png
#   inflating: 2/1884.png
#   inflating: 2/1885.png
#   inflating: 2/1886.png
#   inflating: 2/1887.png
#   inflating: 2/1888.png
#   inflating: 2/1889.png
#   inflating: 2/189.png
#   inflating: 2/1890.png
#   inflating: 2/1891.png
#   inflating: 2/1892.png
#   inflating: 2/1893.png
#   inflating: 2/1894.png
#   inflating: 2/1895.png
#   inflating: 2/1896.png
#   inflating: 2/1897.png
#   inflating: 2/1898.png
#   inflating: 2/1899.png
#   inflating: 2/19.png
#   inflating: 2/190.png
#   inflating: 2/1900.png
#   inflating: 2/1901.png
#   inflating: 2/1902.png
#   inflating: 2/1903.png
#   inflating: 2/1904.png
#   inflating: 2/1905.png
#   inflating: 2/1906.png
#   inflating: 2/1907.png
#   inflating: 2/1908.png
#   inflating: 2/1909.png
#   inflating: 2/191.png
#   inflating: 2/1910.png
#   inflating: 2/1911.png
#   inflating: 2/1912.png
#   inflating: 2/1913.png
#   inflating: 2/1914.png
#   inflating: 2/1915.png
#   inflating: 2/1916.png
#   inflating: 2/1917.png
#   inflating: 2/1918.png
#   inflating: 2/1919.png
#   inflating: 2/192.png
#   inflating: 2/1920.png
#   inflating: 2/1921.png
#   inflating: 2/1922.png
#   inflating: 2/1923.png
#   inflating: 2/1924.png
#   inflating: 2/1925.png
#   inflating: 2/1926.png
#   inflating: 2/1927.png
#   inflating: 2/1928.png
#   inflating: 2/1929.png
#   inflating: 2/193.png
#   inflating: 2/1930.png
#   inflating: 2/1931.png
#   inflating: 2/1932.png
#   inflating: 2/1933.png
#   inflating: 2/1934.png
#   inflating: 2/1935.png
#   inflating: 2/1936.png
#   inflating: 2/1937.png
#   inflating: 2/1938.png
#   inflating: 2/1939.png
#   inflating: 2/194.png
#   inflating: 2/1940.png
#   inflating: 2/1941.png
#   inflating: 2/1942.png
#   inflating: 2/1943.png
#   inflating: 2/1944.png
#   inflating: 2/1945.png
#   inflating: 2/1946.png
#   inflating: 2/1947.png
#   inflating: 2/1948.png
#   inflating: 2/1949.png
#   inflating: 2/195.png
#   inflating: 2/1950.png
#   inflating: 2/1951.png
#   inflating: 2/1952.png
#   inflating: 2/1953.png
#   inflating: 2/1954.png
#   inflating: 2/1955.png
#   inflating: 2/1956.png
#   inflating: 2/1957.png
#   inflating: 2/1958.png
#   inflating: 2/1959.png
#   inflating: 2/196.png
#   inflating: 2/1960.png
#   inflating: 2/1961.png
#   inflating: 2/1962.png
#   inflating: 2/1963.png
#   inflating: 2/1964.png
#   inflating: 2/1965.png
#   inflating: 2/1966.png
#   inflating: 2/1967.png
#   inflating: 2/1968.png
#   inflating: 2/1969.png
#   inflating: 2/197.png
#   inflating: 2/1970.png
#   inflating: 2/1971.png
#   inflating: 2/1973.png
#   inflating: 2/1974.png
#   inflating: 2/1975.png
#   inflating: 2/1976.png
#   inflating: 2/1978.png
#   inflating: 2/1979.png
#   inflating: 2/198.png
# ...
#   inflating: 3/1814.png
#   inflating: 3/1815.png
#   inflating: 3/1816.png
#   inflating: 3/1817.png
#   inflating: 3/1818.png
#   inflating: 3/1819.png
#   inflating: 3/1820.png
#   inflating: 3/1821.png
#   inflating: 3/1822.png
#   inflating: 3/1823.png
#   inflating: 3/1824.png
#   inflating: 3/1825.png
#   inflating: 3/1826.png
#   inflating: 3/1827.png
#   inflating: 3/1828.png
#   inflating: 3/1829.png
#   inflating: 3/1830.png
#   inflating: 3/1831.png
#   inflating: 3/1832.png
#   inflating: 3/1833.png
#   inflating: 3/1834.png
#   inflating: 3/1835.png
#   inflating: 3/1836.png
#   inflating: 3/1837.png
#   inflating: 3/1838.png
#   inflating: 3/1839.png
#   inflating: 3/1972.png
#   inflating: 3/1977.png
#   inflating: 3/1983.png
#   inflating: 3/1984.png
#   inflating: 3/1985.png
#   inflating: 3/1992.png
#   inflating: 3/1997.png
#   inflating: 3/1999.png
#   inflating: 3/2000.png
#   inflating: 3/2001.png
#   inflating: 3/2002.png
#   inflating: 3/2003.png
#   inflating: 3/2004.png
#   inflating: 3/2005.png
#   inflating: 3/2006.png
#   inflating: 3/2007.png
#   inflating: 3/2008.png
#   inflating: 3/2009.png
#   inflating: 3/2010.png
#   inflating: 3/2011.png
#   inflating: 3/2012.png
#   inflating: 3/2013.png
#   inflating: 3/2014.png
#   inflating: 3/2015.png
#   inflating: 3/2016.png
#   inflating: 3/2017.png
#   inflating: 3/2018.png
#   inflating: 3/2019.png
#   inflating: 3/2020.png
#   inflating: 3/2021.png
#   inflating: 3/2022.png
#   inflating: 3/2023.png
#   inflating: 3/2024.png
#   inflating: 3/2025.png
#   inflating: 3/2026.png
#   inflating: 3/2027.png
#   inflating: 3/2028.png
#   inflating: 3/2029.png
#   inflating: 3/2030.png
#   inflating: 3/2031.png
#   inflating: 3/2032.png
#   inflating: 3/2033.png
#   inflating: 3/2034.png
#   inflating: 3/2035.png
#   inflating: 3/2036.png
#   inflating: 3/2037.png
#   inflating: 3/2038.png
#   inflating: 3/2039.png
#   inflating: 3/2040.png
#   inflating: 3/2041.png
#   inflating: 3/2042.png
#   inflating: 3/2043.png
#   inflating: 3/2044.png
#   inflating: 3/2045.png
#   inflating: 3/2046.png
#   inflating: 3/2047.png
#   inflating: 3/2048.png
#   inflating: 3/2049.png
#   inflating: 3/2050.png
#   inflating: 3/2051.png
#   inflating: 3/2052.png
#   inflating: 3/2053.png
#   inflating: 3/2054.png
#   inflating: 3/2055.png
#   inflating: 3/2056.png
#   inflating: 3/2057.png
#   inflating: 3/2058.png
#   inflating: 3/2059.png
#   inflating: 3/2060.png
#   inflating: 3/2061.png
#   inflating: 3/2062.png
#   inflating: 3/2063.png
#   inflating: 3/2064.png
#   inflating: 3/2065.png
#   inflating: 3/2066.png
#   inflating: 3/2067.png
#   inflating: 3/2068.png
#   inflating: 3/2069.png
#   inflating: 3/2070.png
#   inflating: 3/2071.png
#   inflating: 3/2072.png
#   inflating: 3/2073.png
#   inflating: 3/2074.png
#   inflating: 3/2075.png
#   inflating: 3/2076.png
#   inflating: 3/2077.png
#   inflating: 3/2078.png
#   inflating: 3/2079.png
#   inflating: 3/2080.png
#   inflating: 3/2081.png
#   inflating: 3/2082.png
#   inflating: 3/2083.png
#   inflating: 3/2084.png
#   inflating: 3/2085.png
#   inflating: 3/2086.png
#   inflating: 3/2087.png
#   inflating: 3/2088.png
#   inflating: 3/2089.png
#   inflating: 3/2090.png
#   inflating: 3/2091.png
#   inflating: 3/2092.png
#   inflating: 3/2093.png
#   inflating: 3/2094.png
#   inflating: 3/2095.png
#   inflating: 3/2096.png
#   inflating: 3/2097.png
#   inflating: 3/2098.png
#   inflating: 3/2099.png
#   inflating: 3/2100.png
#   inflating: 3/2101.png
#   inflating: 3/2102.png
#   inflating: 3/2103.png
#   inflating: 3/2104.png
#   inflating: 3/2105.png
#   inflating: 3/2106.png
#   inflating: 3/2107.png
#   inflating: 3/2108.png
#   inflating: 3/2109.png
#   inflating: 3/2110.png
#   inflating: 3/2111.png
#   inflating: 3/2112.png
#   inflating: 3/2113.png
#   inflating: 3/2114.png
#   inflating: 3/2115.png
#   inflating: 3/2116.png
#   inflating: 3/2117.png
#   inflating: 3/2118.png
#   inflating: 3/2119.png
#   inflating: 3/2120.png
#   inflating: 3/2121.png
#   inflating: 3/2122.png
#   inflating: 3/2123.png
#   inflating: 3/2124.png
#   inflating: 3/2125.png
#   inflating: 3/2126.png
#   inflating: 3/2127.png
#   inflating: 3/2128.png
#   inflating: 3/2129.png
#   inflating: 3/2130.png
#   inflating: 3/2131.png
#   inflating: 3/2132.png
#   inflating: 3/2133.png
#   inflating: 3/2134.png
#   inflating: 3/2135.png
#   inflating: 3/2136.png
#   inflating: 3/2137.png
#   inflating: 3/2138.png
#   inflating: 3/2139.png
#   inflating: 3/2140.png
#   inflating: 3/2141.png
#   inflating: 3/2142.png
#   inflating: 3/2143.png
#   inflating: 3/2144.png
#   inflating: 3/2145.png
#   inflating: 3/2146.png
#   inflating: 3/2147.png
#   inflating: 3/2148.png
#   inflating: 3/2149.png
#   inflating: 3/2150.png
#   inflating: 3/2151.png
#   inflating: 3/2152.png
#   inflating: 3/2153.png
#   inflating: 3/2154.png
#   inflating: 3/2155.png
#   inflating: 3/2156.png
#   inflating: 3/2157.png
#   inflating: 3/2158.png
#   inflating: 3/2159.png
#   inflating: 3/2160.png
#   inflating: 3/2161.png
#   inflating: 3/2162.png
#   inflating: 3/2163.png
#   inflating: 3/2164.png
#   inflating: 3/2165.png
#   inflating: 3/2166.png
#   inflating: 3/2167.png
#   inflating: 3/2168.png
#   inflating: 3/2169.png
#   inflating: 3/2170.png
#   inflating: 3/2171.png
#   inflating: 3/2172.png
#   inflating: 3/2173.png
#   inflating: 3/2174.png
#   inflating: 3/2175.png
#   inflating: 3/2176.png
#   inflating: 3/2177.png
#   inflating: 3/2178.png
#   inflating: 3/2179.png
#   inflating: 3/2180.png
#   inflating: 3/2181.png
#   inflating: 3/2182.png
#   inflating: 3/2183.png
#   inflating: 3/2184.png
#   inflating: 3/2185.png
#   inflating: 3/2186.png
#   inflating: 3/2187.png
#   inflating: 3/2188.png
#   inflating: 3/2189.png
#   inflating: 3/2190.png
#   inflating: 3/2191.png
#   inflating: 3/2192.png
#   inflating: 3/2193.png
#   inflating: 3/2194.png
#   inflating: 3/2195.png
#   inflating: 3/2196.png
#   inflating: 3/2197.png
#   inflating: 3/2198.png
#   inflating: 3/2199.png
#   inflating: 3/2200.png
#   inflating: 3/2201.png
#   inflating: 3/2202.png
#   inflating: 3/2203.png
#   inflating: 3/2204.png
#   inflating: 3/2205.png
#   inflating: 3/2206.png
#   inflating: 3/2207.png
#   inflating: 3/2208.png
#   inflating: 3/2209.png
#   inflating: 3/2210.png
#   inflating: 3/2211.png
#   inflating: 3/2212.png
#   inflating: 3/2213.png
#   inflating: 3/2214.png
#   inflating: 3/2215.png
#   inflating: 3/2216.png
#   inflating: 3/2217.png
#   inflating: 3/2218.png
#   inflating: 3/2219.png
#   inflating: 3/2220.png
#   inflating: 3/2221.png
#   inflating: 3/2222.png
#   inflating: 3/2223.png
#   inflating: 3/2224.png
#   inflating: 3/2225.png
#   inflating: 3/2226.png
#   inflating: 3/2227.png
#   inflating: 3/2228.png
#   inflating: 3/2229.png
#   inflating: 3/2230.png
#   inflating: 3/2231.png
#   inflating: 3/2232.png
#   inflating: 3/2233.png
#   inflating: 3/2234.png
#   inflating: 3/2235.png
#   inflating: 3/2236.png
#   inflating: 3/2237.png
#   inflating: 3/2238.png
#   inflating: 3/2239.png
#   inflating: 3/2240.png
#   inflating: 3/2241.png
#   inflating: 3/2242.png
#   inflating: 3/2243.png
#   inflating: 3/2244.png
#   inflating: 3/2245.png
#   inflating: 3/2246.png
#   inflating: 3/2247.png
#   inflating: 3/2248.png
#   inflating: 3/2249.png
#   inflating: 3/2250.png
#   inflating: 3/2251.png
#   inflating: 3/2252.png
#   inflating: 3/2253.png
#   inflating: 3/2254.png
#   inflating: 3/2255.png
#   inflating: 3/2256.png
#   inflating: 3/2257.png
#   inflating: 3/2258.png
#   inflating: 3/2259.png
#   inflating: 3/2260.png
#   inflating: 3/2261.png
#   inflating: 3/2262.png
#   inflating: 3/2263.png
#   inflating: 3/2264.png
#   inflating: 3/2265.png
#   inflating: 3/2266.png
#   inflating: 3/2267.png
#   inflating: 3/2268.png
#   inflating: 3/2269.png
#   inflating: 3/2270.png
#   inflating: 3/2271.png
#   inflating: 3/2272.png
#   inflating: 3/2273.png
#   inflating: 3/2274.png
#   inflating: 3/2275.png
#   inflating: 3/2276.png
#   inflating: 3/2277.png
#   inflating: 3/2278.png
#   inflating: 3/2279.png
#   inflating: 3/2280.png
#   inflating: 3/2281.png
#   inflating: 3/2282.png
#   inflating: 3/2283.png
#   inflating: 3/2284.png
#   inflating: 3/2285.png
#   inflating: 3/2286.png
#   inflating: 3/2287.png
#   inflating: 3/2288.png
#   inflating: 3/2289.png
#   inflating: 3/2290.png
#   inflating: 3/2291.png
#   inflating: 3/2292.png
#   inflating: 3/2293.png
#   inflating: 3/2294.png
#   inflating: 3/2295.png
#   inflating: 3/2296.png
#   inflating: 3/2297.png
#   inflating: 3/2298.png
#   inflating: 3/2299.png
#   inflating: 3/2693.png
#   inflating: 3/2698.png
#   inflating: 3/2700.png
#   inflating: 3/2705.png
#   inflating: 3/2707.png
#   inflating: 3/2709.png
#   inflating: 3/2821.png
#   inflating: 3/920.png
#   inflating: 3/921.png
#   inflating: 3/922.png
#   inflating: 3/923.png
#   inflating: 3/924.png
#   inflating: 3/925.png
#   inflating: 3/926.png
#   inflating: 3/927.png
#   inflating: 3/928.png
#   inflating: 3/929.png
#   inflating: 3/930.png
#   inflating: 3/931.png
#   inflating: 3/932.png
#   inflating: 3/933.png
#   inflating: 3/934.png
#   inflating: 3/935.png
#   inflating: 3/936.png
#   inflating: 3/937.png
#   inflating: 3/938.png
#   inflating: 3/939.png
#   inflating: 3/940.png
#   inflating: 3/941.png
#   inflating: 3/942.png
#   inflating: 3/943.png
#   inflating: 3/944.png
#   inflating: 3/945.png
#   inflating: 3/946.png
#   inflating: 3/947.png
#   inflating: 3/948.png
#   inflating: 3/949.png
#   inflating: 3/950.png
#   inflating: 3/951.png
#   inflating: 3/952.png
#   inflating: 3/953.png
#   inflating: 3/954.png
#   inflating: 3/955.png
#   inflating: 3/956.png
#   inflating: 3/957.png
#   inflating: 3/958.png
#   inflating: 3/959.png
#   inflating: 3/960.png
#   inflating: 3/961.png
#   inflating: 3/962.png
#   inflating: 3/963.png
#   inflating: 3/964.png
#   inflating: 3/965.png
#   inflating: 3/966.png
#   inflating: 3/967.png
#   inflating: 3/968.png
#   inflating: 3/969.png
#   inflating: 3/970.png
#   inflating: 3/971.png
#   inflating: 3/972.png
#   inflating: 3/973.png
#   inflating: 3/974.png
#   inflating: 3/975.png
#   inflating: 3/976.png
#   inflating: 3/977.png
#   inflating: 3/978.png
#   inflating: 3/979.png
#   inflating: 3/980.png
#   inflating: 3/981.png
#   inflating: 3/982.png
#   inflating: 3/983.png
#   inflating: 3/984.png
#   inflating: 3/985.png
#   inflating: 3/986.png
#   inflating: 3/987.png
#   inflating: 3/988.png
#   inflating: 3/989.png
#   inflating: 3/990.png
#   inflating: 3/991.png
#   inflating: 3/992.png
#   inflating: 3/993.png
#   inflating: 3/994.png
#   inflating: 3/995.png
#   inflating: 3/996.png
#   inflating: 3/997.png
#   inflating: 3/998.png
#   inflating: 3/999.png

# %%
# import the necessary packages
from imutils.perspective import four_point_transform
from skimage import exposure
import matplotlib.pyplot as plt
import numpy as np
import argparse
import imutils
import cv2

# %%
def plt_imshow(title, image):
    # convert the image frame BGR to RGB color space and display it
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %%
def find_color_card(image):
	# load the ArUCo dictionary, grab the ArUCo parameters, and
	# detect the markers in the input image
	arucoDict = cv2.aruco.Dictionary_get(cv2.aruco.DICT_ARUCO_ORIGINAL)
	arucoParams = cv2.aruco.DetectorParameters_create()
	(corners, ids, rejected) = cv2.aruco.detectMarkers(image,
		arucoDict, parameters=arucoParams)

	# try to extract the coordinates of the color correction card
	try:
		# otherwise, we've found the four ArUco markers, so we can
		# continue by flattening the ArUco IDs list
		ids = ids.flatten()

		# extract the top-left marker
		i = np.squeeze(np.where(ids == 923))
		topLeft = np.squeeze(corners[i])[0]

		# extract the top-right marker
		i = np.squeeze(np.where(ids == 1001))
		topRight = np.squeeze(corners[i])[1]

		# extract the bottom-right marker
		i = np.squeeze(np.where(ids == 241))
		bottomRight = np.squeeze(corners[i])[2]

		# extract the bottom-left marker
		i = np.squeeze(np.where(ids == 1007))
		bottomLeft = np.squeeze(corners[i])[3]

	# we could not find color correction card, so gracefully return
	except:
		return None

	# build our list of reference points and apply a perspective
	# transform to obtain a top-down, birds-eye-view of the color
	# matching card
	cardCoords = np.array([topLeft, topRight,
		bottomRight, bottomLeft])
	card = four_point_transform(image, cardCoords)

	# return the color matching card to the calling function
	return card

# %%
# since we are using Jupyter Notebooks we can replace our argument
# parsing code with *hard coded* arguments and values
args = {
    "reference": "/content/1/2455.png",
    "input": "/content/1/2455.png"
}

# %%
# load the reference image and input images from disk
print("[INFO] loading images...")
ref = cv2.imread(args["reference"])
image = cv2.imread(args["input"])

# resize the reference and input images
ref = imutils.resize(ref, width=1000)
image = imutils.resize(image, width=1000)
ref = imutils.rotate(ref, angle=180)

# display the reference and input images to our screen
plt_imshow("Reference", ref)
plt_imshow("Input", image)
# Out:
# [INFO] loading images...

# %%
# find the color matching card in each image
print("[INFO] finding color matching cards...")
refCard = find_color_card(ref)
imageCard = find_color_card(image)

# if the color matching card is not found in either the reference
# image or the input image, gracefully exit
if refCard is None or imageCard is None:
	print("[INFO] could not find color matching card in both images")
# Out:
# [INFO] finding color matching cards...
# [INFO] could not find color matching card in both images

# %%
# show the color matching card in the reference image and input image,
# respectively
plt_imshow("Reference Color Card", refCard)
plt_imshow("Input Color Card", imageCard)

# apply histogram matching from the color matching card in the
# reference image to the color matching card in the input image
print("[INFO] matching images...")
imageCard = exposure.match_histograms(imageCard, refCard,
	multichannel=True)

# show our input color matching card after histogram matching
plt_imshow("Input Color Card After Matching", imageCard)
# Out:
# [INFO] matching images...

# %% [markdown]
# hi_detect_low_contrast

# %% [markdown]
# hi_gamma_correction

# %%
# import the necessary packages
from matplotlib import pyplot as plt
from __future__ import print_function
import numpy as np
import argparse
import cv2

# %%
def plt_imshow(title, image):
	# convert the image frame BGR to RGB color space and display it
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %%
def adjust_gamma(image, gamma=1.0):
	# build a lookup table mapping the pixel values [0, 255] to
	# their adjusted gamma values
	invGamma = 1.0 / gamma
	table = np.array([((i / 255.0) ** invGamma) * 255
		for i in np.arange(0, 256)]).astype("uint8")

	# apply gamma correction using the lookup table
	return cv2.LUT(image, table)

# %%
# since we are using Jupyter Notebooks we can replace our argument
# parsing code with *hard coded* arguments and values
args = {
	"image": "/content/1/2300.png"
}

# %%
# load the original image
original = cv2.imread(args["image"])

# loop over various values of gamma
for gamma in np.arange(0.0, 3.5, 0.5):
	# ignore when gamma is 1 (there will be no change to the image)
	if gamma == 1:
		continue

	# apply gamma correction and show the images
	gamma = gamma if gamma > 0 else 0.1
	adjusted = adjust_gamma(original, gamma=gamma)
	cv2.putText(adjusted, "g={}".format(gamma), (10, 30),
		cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 3)
	plt_imshow("Images", np.hstack([original, adjusted]))

# %% [markdown]
# hi_histogram

# %%
# import the necessary packages
import matplotlib.pyplot as plt
import numpy as np
import imutils
import cv2

# %%
def plt_imshow(title, image):
    # convert the image frame BGR to RGB color space and display it
    if len(image.shape) == 3:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image)
    plt.title(title)
    plt.grid(False)
    plt.show()

# %%
def plot_histogram(image, title, mask=None):
	# split the image into its respective channels, then initialize
	# the tuple of channel names along with our figure for plotting
	chans = cv2.split(image)
	colors = ("b", "g", "r")
	plt.figure()
	plt.title(title)
	plt.xlabel("Bins")
	plt.ylabel("# of Pixels")

	# loop over the image channels
	for (chan, color) in zip(chans, colors):
		# create a histogram for the current channel and plot it
		hist = cv2.calcHist([chan], [0], mask, [256], [0, 256])
		plt.plot(hist, color=color)
		plt.xlim([0, 256])

	plt.show()

# %%
# since we are using Jupyter Notebooks we can replace our argument
# parsing code with *hard coded* arguments and values
args = {
    "image": "/content/1/2300.png"
}

# %%
# load the input image and convert it to grayscale
image = cv2.imread(args["image"])
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
# compute a grayscale histogram
hist = cv2.calcHist([image], [0], None, [256], [0, 256])

# %%
# matplotlib expects RGB images so convert and then display the image
# with matplotlib
plt.figure()
plt.axis("off")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_GRAY2RGB))

# plot the histogram
plt.figure()
plt.title("Grayscale Histogram")
plt.xlabel("Bins")
plt.ylabel("# of Pixels")
plt.plot(hist)
plt.xlim([0, 256])
# Out:
# (0.0, 256.0)

# %%
# normalize the histogram
hist /= hist.sum()

# plot the normalized histogram
plt.figure()
plt.title("Grayscale Histogram (Normalized)")
plt.xlabel("Bins")
plt.ylabel("% of Pixels")
plt.plot(hist)
plt.xlim([0, 256])
plt.show()

# %%
# load the input image from disk
image = cv2.imread(args["image"])

# %%
# split the image into its respective channels, then initialize the
# tuple of channel names along with our figure for plotting
chans = cv2.split(image)
colors = ("b", "g", "r")
plt.figure()
plt.title("'Flattened' Color Histogram")
plt.xlabel("Bins")
plt.ylabel("# of Pixels")

# loop over the image channels
for (chan, color) in zip(chans, colors):
	# create a histogram for the current channel and plot it
	hist = cv2.calcHist([chan], [0], None, [256], [0, 256])
	plt.plot(hist, color=color)
	plt.xlim([0, 256])

# %%
# create a new figure and then plot a 2D color histogram for the
# green and blue channels
fig = plt.figure(figsize=(15, 25))
ax = fig.add_subplot(131)
hist = cv2.calcHist([chans[1], chans[0]], [0, 1], None, [32, 32],
	[0, 256, 0, 256])
p = ax.imshow(hist, interpolation="nearest")
ax.set_title("2D Color Histogram for G and B")
plt.colorbar(p)

# plot a 2D color histogram for the green and red channels
ax = fig.add_subplot(132)
hist = cv2.calcHist([chans[1], chans[2]], [0, 1], None, [32, 32],
	[0, 256, 0, 256])
p = ax.imshow(hist, interpolation="nearest")
ax.set_title("2D Color Histogram for G and R")
plt.colorbar(p)

# plot a 2D color histogram for blue and red channels
ax = fig.add_subplot(133)
hist = cv2.calcHist([chans[0], chans[2]], [0, 1], None, [32, 32],
	[0, 256, 0, 256])
p = ax.imshow(hist, interpolation="nearest")
ax.set_title("2D Color Histogram for B and R")
plt.colorbar(p)

# finally, let's examine the dimensionality of one of the 2D
# histograms
print("2D histogram shape: {}, with {} values".format(
	hist.shape, hist.flatten().shape[0]))
# Out:
# 2D histogram shape: (32, 32), with 1024 values

# %%
# our 2D histogram could only take into account 2 out of the 3
# channels in the image so now let's build a 3D color histogram
# (utilizing all channels) with 8 bins in each direction -- we
# can't plot the 3D histogram, but the theory is exactly like
# that of a 2D histogram, so we'll just show the shape of the
# histogram
hist = cv2.calcHist([image], [0, 1, 2],
	None, [8, 8, 8], [0, 256, 0, 256, 0, 256])
print("3D histogram shape: {}, with {} values".format(
	hist.shape, hist.flatten().shape[0]))
# Out:
# 3D histogram shape: (8, 8, 8), with 512 values

# %%
# display the original input image
plt.figure()
plt.axis("off")
plt.imshow(imutils.opencv2matplotlib(image))

# show our plots
plt.show()

# %%
# load the beach image and plot a histogram for it
image = cv2.imread("/content/1/2300.png")
plot_histogram(image, "Histogram for Original Image")
plt_imshow("Original", image)

# %%
# construct a mask for our image; our mask will be *black* for regions
# we want to *ignore* and *white* for regions we want to *examine*
mask = np.zeros(image.shape[:2], dtype="uint8")
cv2.rectangle(mask, (60, 290), (210, 390), 255, -1)
plt_imshow("Mask", mask)

# display the masked region
masked = cv2.bitwise_and(image, image, mask=mask)
plt_imshow("Applying the Mask", masked)

# compute a histogram for our image, but we'll only include pixels in
# the masked region
plot_histogram(image, "Histogram for Masked Image", mask=mask)

# show our plots
plt.show()

# %% [markdown]
# hi_histogram_equalization

# %%
# since we are using Jupyter Notebooks we can replace our argument
# parsing code with *hard coded* arguments and values
args = {
    "image": "/content/1/2300.png"
}

# %%
# load the input image from disk and convert it to grayscale
print("[INFO] loading input image...")
image = cv2.imread(args["image"])
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# apply histogram equalization
print("[INFO] performing histogram equalization...")
equalized = cv2.equalizeHist(gray)
# Out:
# [INFO] loading input image...
# [INFO] performing histogram equalization...

# %%
# show the original grayscale image and equalized image
plt_imshow("Input", gray)
plt_imshow("Histogram Equalization", equalized)

# %%
# since we are using Jupyter Notebooks we can replace our argument
# parsing code with *hard coded* arguments and values
args = {
    "image": "/content/1/2300.png",
    "clip": 2.0,
    "tile": 8
}

# %%
# load the input image from disk and convert it to grayscale
print("[INFO] loading input image...")
image = cv2.imread(args["image"])
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# apply CLAHE (Contrast Limited Adaptive Histogram Equalization)
print("[INFO] applying CLAHE...")
clahe = cv2.createCLAHE(clipLimit=args["clip"],
	tileGridSize=(args["tile"], args["tile"]))
equalized = clahe.apply(gray)
# Out:
# [INFO] loading input image...
# [INFO] applying CLAHE...

# %%
#show the original grayscale image and CLAHE output image
plt_imshow("Input", gray)
plt_imshow("CLAHE", equalized)

# %% [markdown]
# hi_histogram_matching

# %%
# since we are using Jupyter Notebooks we can replace our argument
# parsing code with *hard coded* arguments and values
args = {
    "source": "/content/1/2300.png",
    "reference": "/content/1/2301.png"
}

# %%
# load the source and reference images
print("[INFO] loading source and reference images...")
src = cv2.imread(args["source"])
ref = cv2.imread(args["reference"])

# determine if we are performing multichannel histogram matching
# and then perform histogram matching itself
print("[INFO] performing histogram matching...")
multi = True if src.shape[-1] > 1 else False
matched = exposure.match_histograms(src, ref, multichannel=multi)

# show the output images
plt_imshow("Source", src)
plt_imshow("Reference", ref)
plt_imshow("Matched", matched)
# Out:
# [INFO] loading source and reference images...
# [INFO] performing histogram matching...

# %%
# construct a figure to display the histogram plots for each channel
# before and after histogram matching was applied
(fig, axs) =  plt.subplots(nrows=3, ncols=3, figsize=(8, 8))

# loop over our source image, reference image, and output matched
# image
for (i, image) in enumerate((src, ref, matched)):
	# convert the image from BGR to RGB channel ordering
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

	# loop over the names of the channels in RGB order
	for (j, color) in enumerate(("red", "green", "blue")):
		# compute a histogram for the current channel and plot it
		(hist, bins) = exposure.histogram(image[..., j],
			source_range="dtype")
		axs[j, i].plot(bins, hist / hist.max())

		# compute the cumulative distribution function for the
		# current channel and plot it
		(cdf, bins) = exposure.cumulative_distribution(image[..., j])
		axs[j, i].plot(bins, cdf)

		# set the y-axis label of the current plot to be the name
		# of the current color channel
		axs[j, 0].set_ylabel(color)
  
# set the axes titles
axs[0, 0].set_title("Source")
axs[0, 1].set_title("Reference")
axs[0, 2].set_title("Matched")
# Out:
# Text(0.5, 1.0, 'Matched')
